# %% [markdown]
# NAME: AKSHAR MODI

# %% [markdown]
# # TASK 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime

# %% [markdown]
# # TASK 2

# %%
strsale=pd.read_excel("Superstore.xls")
strsale.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
strsale.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
strsale.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
strsale.notnull().head(50)#Find out are there any missing or null values in the data for all columns
# Out:
#     Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0     True      True        True       True       True         True
# 1     True      True        True       True       True         True
# 2     True      True        True       True       True         True
# 3     True      True        True       True       True         True
# 4     True      True        True       True       True         True
# 5     True      True        True       True       True         True
# 6     True      True        True       True       True         True
# 7     True      True        True       True       True         True
# 8     True      True        True       True       True         True
# 9     True      True        True       True       True         True
# 10    True      True        True       True       True         True
# 11    True      True        True       True       True         True
# 12    True      True        True       True       True         True
# ...

# %% [markdown]
# # TASK 3

# %%
strsale['Order Date']=pd.to_datetime(strsale['Order Date'])
strsale['Ship Date']=pd.to_datetime(strsale['Ship Date'])

# %%
strsale.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# NAME: AKSHAR MODI

# %%
strsale['Product ID'].unique
# Out:
# <bound method Series.unique of 0       FUR-BO-10001798
# 1       FUR-CH-10000454
# 2       OFF-LA-10000240
# 3       FUR-TA-10000577
# 4       OFF-ST-10000760
#              ...
# 9989    FUR-FU-10001889
# 9990    FUR-FU-10000747
# 9991    TEC-PH-10003645
# 9992    OFF-PA-10004041
# 9993    OFF-AP-10002684
# Name: Product ID, Length: 9994, dtype: object>

# %%
strsale['price_per_unit']=strsale['Sales']/strsale['Quantity'] #Find out the per unit price from the data

# %%
strsale.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ... Region  \
# ...

# %% [markdown]
# # TASK 4

# %%
#strsale['year'] = pd.DatetimeIndex(strsale['Order Date']).year
# strsale['month'] = pd.DatetimeIndex(strsale['Order Date']).month

# %%
#strsale.drop(['year', 'month'], axis=1, inplace=True)

# %%
strsale['month_year'] = pd.to_datetime(strsale['Order Date']).dt.to_period('M')

# %%
strsale.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...       Product ID  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  FUR-BO-10001798
# 1   Claire Gute  Consumer  United States  Henderson  ...  FUR-CH-10000454
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases                  Bush Somerset Collection Bookcase
# 1  Furniture       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
#
#     Sales Quantity Discount    Profit  price_per_unit  month_year
# 0  261.96        2      0.0   41.9136          130.98     2016-11
# 1  731.94        3      0.0  219.5820          243.98     2016-11
#
# [2 rows x 23 columns]

# %%
strsale1=strsale.set_index('month_year').groupby(pd.Grouper(freq="M"))

# %%
#strsale1.describe()

# %%
ak=pd.DataFrame()

# %%
ak['month']=strsale['month_year']

# %%
ak['revenue']=strsale['Sales']

# %%
ak=ak.groupby(['month'])['revenue'].sum()

# %%
ak.head()
# Out:
# month
# 2014-01    14236.895
# 2014-02     4519.892
# 2014-03    55691.009
# 2014-04    28295.345
# 2014-05    23648.287
# Freq: M, Name: revenue, dtype: float64

# %%
ak.plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# NAME: AKSHAR MODI

# %% [markdown]
# # TASK 5

# %%
strsale['year'] = pd.DatetimeIndex(strsale['Order Date']).year

# %%
ak1=pd.DataFrame()

# %%
ak1['year']=strsale['year']

# %%
ak1['revenue']=strsale['Sales']

# %%
ak1=ak1.groupby(['year'])['revenue'].sum()

# %%
ak1.head(5)
# Out:
# year
# 2014    484247.4981
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: revenue, dtype: float64

# %%
ak1.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # TASK 6

# %%
len(ak)
# Out:
# 48

# %%
len(ak1)
# Out:
# 4

# %%
ak.values
# Out:
# array([ 14236.895 ,   4519.892 ,  55691.009 ,  28295.345 ,  23648.287 ,
#         34595.1276,  33946.393 ,  27909.4685,  81777.3508,  31453.393 ,
#         78628.7167,  69545.6205,  18174.0756,  11951.411 ,  38726.252 ,
#         34195.2085,  30131.6865,  24797.292 ,  28765.325 ,  36898.3322,
#         64595.918 ,  31404.9235,  75972.5635,  74919.5212,  18542.491 ,
#         22978.815 ,  51715.875 ,  38750.039 ,  56987.728 ,  40344.534 ,
#         39261.963 ,  31115.3743,  73410.0249,  59687.745 ,  79411.9658,
#         96999.043 ,  43971.374 ,  20301.1334,  58872.3528,  36521.5361,
#         44261.1102,  52981.7257,  45264.416 ,  63120.888 ,  87866.652 ,
#         77776.9232, 118447.825 ,  83829.3188])

# %%
ak=pd.DataFrame(ak)

# %%
#ak=ak.drop(['diff'], axis=1)

# %%
ak['growth_rate']=ak.pct_change()

# %%
ak = ak.fillna(value=0)

# %%
ak.head(20)
# Out:
#             revenue  growth_rate
# month
# 2014-01  14236.8950     0.000000
# 2014-02   4519.8920    -0.682523
# 2014-03  55691.0090    11.321314
# 2014-04  28295.3450    -0.491923
# 2014-05  23648.2870    -0.164234
# 2014-06  34595.1276     0.462902
# 2014-07  33946.3930    -0.018752
# 2014-08  27909.4685    -0.177837
# 2014-09  81777.3508     1.930093
# 2014-10  31453.3930    -0.615378
# 2014-11  78628.7167     1.499848
# 2014-12  69545.6205    -0.115519
# 2015-01  18174.0756    -0.738674
# 2015-02  11951.4110    -0.342392
# 2015-03  38726.2520     2.240308
# 2015-04  34195.2085    -0.117002
# 2015-05  30131.6865    -0.118833
# 2015-06  24797.2920    -0.177036
# 2015-07  28765.3250     0.160019
# 2015-08  36898.3322     0.282736

# %%
print(max(ak['growth_rate']))
# Out:
# 11.321314093345597

# %%
ak.plot(y='growth_rate', use_index=True)
# Out:
# C:\Users\Akshar\anaconda3\envs\tensorflow\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# # TASK 7

# %%
ak2=pd.DataFrame()

# %%
ak2['product_ID']=strsale['Product ID']

# %%
ak2['quantity']=strsale['Quantity']

# %%
ak2=ak2.groupby(['product_ID'])['quantity'].sum()

# %%
ak2.head(10)
# Out:
# product_ID
# FUR-BO-10000112     9
# FUR-BO-10000330    10
# FUR-BO-10000362    14
# FUR-BO-10000468    21
# FUR-BO-10000711    12
# FUR-BO-10000780    22
# FUR-BO-10001337    28
# FUR-BO-10001519    22
# FUR-BO-10001567     3
# FUR-BO-10001601    10
# Name: quantity, dtype: int64

# %%
ak2=pd.DataFrame(ak2)

# %%
print(ak2['quantity'].idxmax())
# Out:
# TEC-AC-10003832

# %%
max_sold_product=ak2['quantity'].idxmax()

# %%
print(strsale['Product Name'][strsale['Product ID']==max_sold_product])
# Out:
# 235                    Logitech P710e Mobile Speakerphone
# 251                    Logitech P710e Mobile Speakerphone
# 524     Imation 16GB Mini TravelDrive USB 2.0 Flash Drive
# 643     Imation 16GB Mini TravelDrive USB 2.0 Flash Drive
# 675     Imation 16GB Mini TravelDrive USB 2.0 Flash Drive
# 1653    Imation 16GB Mini TravelDrive USB 2.0 Flash Drive
# 1910    Imation 16GB Mini TravelDrive USB 2.0 Flash Drive
# 2666    Imation 16GB Mini TravelDrive USB 2.0 Flash Drive
# 3370                   Logitech P710e Mobile Speakerphone
# 5018                   Logitech P710e Mobile Speakerphone
# 5022                   Logitech P710e Mobile Speakerphone
# 5552    Imation 16GB Mini TravelDrive USB 2.0 Flash Drive
# 6477                   Logitech P710e Mobile Speakerphone
# 7279    Imation 16GB Mini TravelDrive USB 2.0 Flash Drive
# 8586                   Logitech P710e Mobile Speakerphone
# 8734                   Logitech P710e Mobile Speakerphone
# ...

# %% [markdown]
# # TASK 8

# %%
ak3=pd.DataFrame()

# %%
ak3['name']=strsale['Customer Name']

# %%
ak3['quantity']=strsale['Quantity']

# %%
ak3.head(5)
# Out:
#               name  quantity
# 0      Claire Gute         2
# 1      Claire Gute         3
# 2  Darrin Van Huff         2
# 3   Sean O'Donnell         5
# 4   Sean O'Donnell         2

# %%
ak3=ak3.groupby(['name'])['quantity'].sum()

# %%
ak3=pd.DataFrame(ak3)

# %%
ak3.head(4)
# Out:
#                  quantity
# name
# Aaron Bergman          13
# Aaron Hawkins          54
# Aaron Smayling         48
# Adam Bellavance        56

# %%
len(ak3)
# Out:
# 793

# %%
print(ak3['quantity'].idxmax())
# Out:
# Jonathan Doherty

# %% [markdown]
# NAME: AKSHAR MODI

# %% [markdown]
# # TASK 9

# %%
ak4=pd.DataFrame()
ak4['name']=strsale['Customer Name']
ak4['revenuep']=strsale['Sales']

# %%
ak4.head(4)
# Out:
#               name  revenuep
# 0      Claire Gute  261.9600
# 1      Claire Gute  731.9400
# 2  Darrin Van Huff   14.6200
# 3   Sean O'Donnell  957.5775

# %%
ak4=ak4.groupby(['name'])['revenuep'].sum()

# %%
ak4=pd.DataFrame(ak4)

# %%
ak4.head(4)
# Out:
#                  revenuep
# name
# Aaron Bergman     886.156
# Aaron Hawkins    1744.700
# Aaron Smayling   3050.692
# Adam Bellavance  7755.620

# %%
print(ak4['revenuep'].idxmax())
print(ak4['revenuep'].max())
# Out:
# Sean Miller
# 25043.05

# %% [markdown]
# # TASK 10

# %%
ak5=pd.DataFrame()

# %%
ak5['city']=strsale['City']

# %%
ak5['custo_name']=strsale['Customer Name']

# %%
ak5.head(4)
# Out:
#               city       custo_name
# 0        Henderson      Claire Gute
# 1        Henderson      Claire Gute
# 2      Los Angeles  Darrin Van Huff
# 3  Fort Lauderdale   Sean O'Donnell

# %%
g1 = ak5.groupby(["city"]).size().reset_index(name='Number of customers')

# %%
g1
# Out:
#             city  Number of customers
# 0       Aberdeen                    1
# 1        Abilene                    1
# 2          Akron                   21
# 3    Albuquerque                   14
# 4     Alexandria                   16
# ..           ...                  ...
# 526   Woonsocket                    4
# 527      Yonkers                   15
# 528         York                    5
# 529      Yucaipa                    1
# 530         Yuma                    4
#
# [531 rows x 2 columns]

# %%
print(g1.max())
# Out:
# city                   Yuma
# Number of customers     915
# dtype: object

# %%
print(g1.min())
# Out:
# city                   Aberdeen
# Number of customers           1
# dtype: object

# %%
#ak5=ak5.drop('custo_name',axis=1)

# %%
ak5['sales']=strsale['Sales']

# %%
ak5.head(4)
# Out:
#               city     sales
# 0        Henderson  261.9600
# 1        Henderson  731.9400
# 2      Los Angeles   14.6200
# 3  Fort Lauderdale  957.5775

# %%
ak5=ak5.groupby(['city'])['sales'].sum()

# %%
ak5.head(4)
# Out:
#                 sales
# city
# Aberdeen       25.500
# Abilene         1.392
# Akron        2729.986
# Albuquerque  2220.160

# %%
ak5=pd.DataFrame(ak5)

# %%
print(ak5['sales'].idxmax())
print(ak5['sales'].max())
# Out:
# New York City
# 256368.161

# %%
print(ak5['sales'].idxmin())
print(ak5['sales'].min())
# Out:
# Abilene
# 1.3919999999999997

# %%
ak6=pd.DataFrame()

# %%
ak6['city']=strsale['City']

# %%
ak6['quanti']=strsale['Quantity']

# %%
ak6.head(4)
# Out:
#               city  quanti
# 0        Henderson       2
# 1        Henderson       3
# 2      Los Angeles       2
# 3  Fort Lauderdale       5

# %%
ak6=ak6.groupby(['city'])['quanti'].sum()

# %%
ak6=pd.DataFrame(ak6)

# %%
ak6.head(4)
# Out:
#              quanti
# city
# Aberdeen          3
# Abilene           2
# Akron            65
# Albuquerque      65

# %%
print(ak6['quanti'].idxmax())
print(ak6['quanti'].max())
# Out:
# New York City
# 3417

# %%
print(ak6['quanti'].idxmin())
print(ak6['quanti'].min())
# Out:
# Elyria
# 1

# %% [markdown]
# NAME: AKSHAR MODI

# %% [markdown]
# # TASK 11

# %%
ak7=pd.DataFrame()

# %%
ak7['category']=strsale['Category']

# %%
ak7['quanti']=strsale['Quantity']

# %%
ak7.head(4)
# Out:
#           category  quanti
# 0        Furniture       2
# 1        Furniture       3
# 2  Office Supplies       2
# 3        Furniture       5

# %%
ak7=ak7.groupby(['category'])['quanti'].sum()

# %%
ak7=pd.DataFrame(ak7)

# %%
ak7.head(4)
# Out:
#                  quanti
# category
# Furniture          8028
# Office Supplies   22906
# Technology         6939

# %%
print(ak7['quanti'].idxmax())
print(ak7['quanti'].max())
# Out:
# Office Supplies
# 22906

# %%
print(ak7['quanti'].idxmin())
print(ak7['quanti'].min())
# Out:
# Technology
# 6939

# %%
ak8=pd.DataFrame()
ak8['category']=strsale['Category']
ak8['sales']=strsale['Sales']
ak8=ak8.groupby(['category'])['sales'].sum()
ak8=pd.DataFrame(ak8)

# %%
ak8.head(4)
# Out:
#                        sales
# category
# Furniture        741999.7953
# Office Supplies  719047.0320
# Technology       836154.0330

# %%
print(ak8['sales'].idxmax())
print(ak8['sales'].max())
# Out:
# Technology
# 836154.0329999966

# %%
print(ak8['sales'].idxmin())
print(ak8['sales'].min())
# Out:
# Office Supplies
# 719047.0320000029

# %% [markdown]
# # TASK 12

# %%
ak9=pd.DataFrame()
ak9['sub_category']=strsale['Sub-Category']
ak9['sales']=strsale['Sales']
ak9=ak9.groupby(['sub_category'])['sales'].sum()
ak9=pd.DataFrame(ak9)

# %%
ak9.head(4)
# Out:
#                    sales
# sub_category
# Accessories   167380.318
# Appliances    107532.161
# Art            27118.792
# Binders       203412.733

# %%
print(ak9['sales'].idxmax())
print(ak9['sales'].max())
# Out:
# Phones
# 330007.0540000001

# %%
print(ak9['sales'].idxmin())
print(ak9['sales'].min())
# Out:
# Fasteners
# 3024.2799999999997

# %%
ak10=pd.DataFrame()
ak10['sub_category']=strsale['Sub-Category']
ak10['quanti']=strsale['Quantity']
ak10=ak10.groupby(['sub_category'])['quanti'].sum()
ak10=pd.DataFrame(ak10)

# %%
ak10.head(4)
# Out:
#               quanti
# sub_category
# Accessories     2976
# Appliances      1729
# Art             3000
# Binders         5974

# %%
print(ak10['quanti'].idxmax())
print(ak10['quanti'].max())
# Out:
# Binders
# 5974

# %%
print(ak10['quanti'].idxmin())
print(ak10['quanti'].min())
# Out:
# Copiers
# 234

# %% [markdown]
# # END#################################################################################################

# %% [markdown]
# NAME: AKSHAR MODI
